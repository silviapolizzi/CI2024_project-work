# %%
import random
from typing import Dict, Optional, List
import numpy as np

# %%
# Definizioni per gli operatori
BINARY_OPERATORS = ['+', '-', '*', '/', '**', 'mod']
UNARY_OPERATORS = ['sin', 'cos', 'exp', 'log', 'sqrt', 'tan', 'tanh', 'sinh', 'cosh', 'abs']
OPERATOR_WEIGHTS = {
    '+': 0.3,
    '-': 0.3,
    '*': 0.2,
    '/': 0.1,    # Divisioni meno frequenti
    '**': 0.05,  # Potenze rare
    'sin': 0.15,
    'cos': 0.15,
    'exp': 0.05, # Exponential molto raro
    'log': 0.1,
    'sqrt': 0.1,
    'tan': 0.05,
    'tanh': 0.05,
    'sinh': 0.05,
    'cosh': 0.05,
    'abs': 0.05,
    'log10': 0.05,
    'log2': 0.05,
    'mod': 0.05
}


# Configurazioni per la mutazione
class MutationConfig:
    MUTATION_WEIGHTS = {
        'SUBTREE': 0.4,
        'OPERATOR': 0.4,
        'VALUE': 0.2,
    }
    SUBTREE_DEPTH_RANGE = (1, 3)
    VALUE_STEP_FACTOR = 0.1
    MUTATION_DECAY = 0.5

# Funzione per limitare i valori
CLIP_MIN = -1e6
CLIP_MAX = 1e6

MAX_POWER = 5


def clip_value(value):
    return np.clip(value, CLIP_MIN, CLIP_MAX)

# Implementazione delle operazioni sicure
def safe_divide(a, b):
    return a / b if b != 0 else 0


def safe_sin(x):
    x = np.clip(x, -1000, 1000)  # Clip the input to avoid excessive values
    result = np.sin(x)
    return np.clip(result, -1000, 1000)

def safe_cos(x):
    x = np.clip(x, -1000, 1000)  # Clip the input to avoid excessive values
    result = np.cos(x)
    return np.clip(result, -1000, 1000)

def safe_sinh(x):
    x = np.clip(x, -100, 100)  # Limiting input to prevent overflow
    result = np.sinh(x)
    return np.clip(result, -1000, 1000)

def safe_cosh(x):
    x = np.clip(x, -100, 100)  # Limiting input to prevent overflow
    result = np.cosh(x)
    return np.clip(result, -1000, 1000)

def safe_tan(x):
    if np.isclose(np.mod(x, np.pi), np.pi / 2):  # tan is undefined at odd multiples of pi/2
        return float(10**6)
    x = np.clip(x, -1000, 1000)  # Clip the input to a manageable range
    result = np.tan(x)
    return np.clip(result, -1000, 1000)

def safe_log10(x):
    if x <= 0:
        return float(10**6)
    result = np.log10(x)
    return np.clip(result, -1000, 1000)

def safe_pow(base, exp):
    base = np.clip(base, -1000, 1000)  # Limiting base
    exp = np.clip(exp, -1000, 1000)    # Limiting exponent
    if base == 0 and exp < 0:
        return float(10**6)  # Return large penalty for invalid operation
    elif base < 0 and not exp.is_integer():
        return float(10**6)
    try:
        result = np.power(base, exp)
        return np.clip(result, -1000, 1000)
    except ValueError:
        return float(10**6)

def safe_log2(x):
    if x <= 0:
        return float(10**6)
    result = np.log2(x)
    return np.clip(result, -1000, 1000)

def safe_mod(x, y):
    if y == 0:
        return float(10**6)
    x = np.clip(x, -1000, 1000)
    y = np.clip(y, -1000, 1000)
    result = np.mod(x, y)
    return np.clip(result, -1000, 1000)

def safe_tanh(x):
    x = np.clip(x, -1000, 1000)  # Limiting large inputs to avoid overflow
    result = np.tanh(x)
    return np.clip(result, -1000, 1000)

def safe_exp(x):
    x = np.clip(x, -100, 100)  # Limiting input to prevent overflow
    result = np.exp(x)
    return np.clip(result, -1000, 1000)

def safe_log(x):
    if x <= 0:
        return float(10**6)
    result = np.log(x)
    return np.clip(result, -1000, 1000)

def safe_sqrt(x):
    x = np.maximum(x, 0)  # Ensure input is non-negative
    result = np.sqrt(x)
    return np.clip(result, -1000, 1000)

def safe_abs(x):
    result = np.abs(x)
    return np.clip(result, -1000, 1000)

SAFE_OPERATIONS = {
    '+': lambda a, b: a + b,
    '-': lambda a, b: a - b,
    '*': lambda a, b: a * b,
    '/': safe_divide,
    'sin': safe_sin,
    'cos': safe_cos,
    'exp': safe_exp,
    'log': safe_log,
    'sqrt': safe_sqrt,
    'tan': safe_tan,
    'tanh': safe_tanh,
    'sinh': safe_sinh,
    'cosh': safe_cosh,
    'abs': safe_abs,
    'log10': safe_log10,
    'log2': safe_log2,
    '**': safe_pow,
    'mod': safe_mod
}

class Node:
    def __init__(self, value=None, op=None, left=None, right=None):
        self.value = value
        self.op = op
        self.left = left
        self.right = right

    def evaluate(self, x):
        try:
            if self.op in BINARY_OPERATORS:
                if not self.left or not self.right:
                    return 0
                left_val = self.left.evaluate(x)
                right_val = self.right.evaluate(x)
                return SAFE_OPERATIONS[self.op](left_val, right_val)
            elif self.op in UNARY_OPERATORS:
                if not self.left:
                    return 0
                operand_val = self.left.evaluate(x)
                return SAFE_OPERATIONS[self.op](operand_val)
            # Evaluate value of input variable 
            elif isinstance(self.value, str) and self.value.startswith("x["):
                index = int(self.value[2:-1])  # extract the index of input array, e.g. x[0] -> 0
                return clip_value(x[index])
            elif self.value is not None:
                return clip_value(self.value)
        except Exception:
            return 0

    def copy(self):  
        return Node(
            value=self.value,
            op=self.op,
            left=self.left.copy() if self.left else None,
            right=self.right.copy() if self.right else None,
        )

    def is_valid(self):
        if self.value is not None:
            return True
        if self.op in BINARY_OPERATORS:
            return self.left is not None and self.right is not None
        if self.op in UNARY_OPERATORS:
            return self.left is not None
        return False

    def __str__(self):
        if self.op in BINARY_OPERATORS:
            return f"({self.left} {self.op} {self.right})"
        elif self.op in UNARY_OPERATORS:
            return f"{self.op}({self.left})"
        else:
            return str(self.value)

# def get_all_nodes(node: Node) -> List[Node]:  SERVE???
#     """Restituisce tutti i nodi dell'albero."""
#     nodes = []
#     def traverse(node):
#         if node is None:
#             return
#         nodes.append(node)
#         traverse(node.left)
#         traverse(node.right)
#     traverse(node)
#     return nodes

# def validate_tree(node: Node, n_variables: int):
#     if node is None or not node.is_valid():
#         # Sostituisci con un nodo foglia valido
#         return Node(generate_constant())
    
    
#     # Valida operatori unari
#     if node.op in UNARY_OPERATORS:
#         if node.op == 'log' and (node.left is None or node.left.evaluate([0]) <= 0):
#             return Node(generate_constant())
    
#     # Valida operatori binari
#     if node.op in BINARY_OPERATORS:
#         if node.op == '/' and (node.right is None or node.right.evaluate([0]) == 0):
#             return Node(generate_constant())
#         if node.op == '**' and (node.left is None or node.right is None or node.right.evaluate([0]) < 0):
#             return Node(generate_constant())

#     if node.left:
#         node.left = validate_tree(node.left, n_variables)
#     if node.right:
#         node.right = validate_tree(node.right, n_variables)
#     return node


def is_possible_non_positive(node: Node) -> bool:
    """Verifica se il sottoalbero può restituire valori <= 0."""
    # Implementa una logica simbolica (es. controlla se contiene operatori o variabili rischiosi)
    # Versione semplificata per esempio:
    if node.value is not None:
        return float(node.value) <= 0
    return True  # Assume rischio se contiene variabili o operatori non deterministici
def is_possible_negative(node: Node) -> bool:
    """Verifica se il sottoalbero può restituire valori < 0."""
    # Versione semplificata: controlla se è una costante negativa
    return node.value is not None and float(node.value) < 0

def is_negative(node: Node) -> bool:
    """Verifica se il sottoalbero restituisce valori negativi."""
    # Versione semplificata: controlla se è una costante negativa
    return node.value is not None and float(node.value) < 0

def is_zero(node: Node) -> bool:
    """Verifica se il sottoalbero restituisce zero."""
    # Versione semplificata: controlla se è una costante zero
    return node.value == 0 or (node.op is None and float(node.value) == 0.0)

def is_integer(node: Node) -> bool:
    """Verifica se il sottoalbero restituisce valori interi."""
    # Versione semplificata: controlla se è una costante intera
    return node.value is not None and float(node.value).is_integer()


def validate_tree(node: Node, n_variables: int) -> Node:
    """
    Ricorsivamente valida e corregge l'albero, garantendo che tutte le operazioni siano sicure.
    Restituisce un NUOVO albero modificato (no in-place).
    """
    if node is None or not node.is_valid():
        return Node(value=generate_constant())  # Crea un nuovo nodo
    
    # Deep copy per evitare side effect
    new_node = Node(value=node.value, op=node.op)
    
    # Controllo operatori unari
    if new_node.op in UNARY_OPERATORS:
        new_node.left = validate_tree(node.left, n_variables)
        if new_node.op == 'log':
            # Se il sottoalbero sinistro può essere <= 0, sostituisci
            if is_possible_non_positive(new_node.left):
                return Node(value=generate_constant())
        elif new_node.op == 'sqrt':
            if is_possible_negative(new_node.left):
                return Node(value=generate_constant())
    
    # Controllo operatori binari
    elif new_node.op in BINARY_OPERATORS:
        new_node.left = validate_tree(node.left, n_variables)
        new_node.right = validate_tree(node.right, n_variables)
        if new_node.op == '/':
            if is_zero(new_node.right):  # Se il denominatore può essere zero
                return Node(value=generate_constant())
        elif new_node.op == '**':
            if is_negative(new_node.left) and not is_integer(new_node.right):
                return Node(value=generate_constant())
        elif new_node.op == 'mod':
            if is_zero(new_node.right):
                return Node(value=generate_constant())
    
    # Se è un nodo foglia (variabile o costante), verifica gli indici
    if isinstance(new_node.value, str) and new_node.value.startswith("x["):
        index = int(new_node.value[2:-1])
        if index < 0 or index >= n_variables:
            return Node(value=generate_constant())  # Indice non valido
    
    return new_node

def mutate(
    node: Node,
    mutation_prob: float,
    max_depth: int,
    n_variables: int,
    config: MutationConfig = MutationConfig(),):
    if random.random() > mutation_prob:
        return node

    mutation_type = random.choices(
        list(config.MUTATION_WEIGHTS.keys()),
        weights=list(config.MUTATION_WEIGHTS.values()),
    )[0]

    if mutation_type == 'SUBTREE':
        return create_random_tree(
            random.randint(*config.SUBTREE_DEPTH_RANGE),
            max_depth,
            n_variables
        )

    elif mutation_type == 'OPERATOR':
    # Cambia operatore con scelta pesata
        if node.op in UNARY_OPERATORS or node.op in BINARY_OPERATORS:
            node.op = choose_operator()


    elif mutation_type == 'VALUE':
        if node.value is not None and isinstance(node.value, (int, float)):
            step = (
                abs(node.value) * config.VALUE_STEP_FACTOR
                if node.value != 0
                else config.VALUE_STEP_FACTOR
            )
            node.value += random.gauss(0, step)

    if node.left:
        node.left = mutate(
            node.left,
            mutation_prob * config.MUTATION_DECAY,
            max_depth,
            n_variables,
            config=config,
        )
    if node.right:
        node.right = mutate(
            node.right,
            mutation_prob * config.MUTATION_DECAY,
            max_depth,
            n_variables,
            config=config,
        )

    return node


def choose_operator():
    operators = list(OPERATOR_WEIGHTS.keys())
    weights = list(OPERATOR_WEIGHTS.values())
    return random.choices(operators, weights=weights, k=1)[0]

def generate_constant():

    if random.random() < 0.5:
        return random.uniform(-1, 1)  # small value
    else:
        return random.uniform(-10, 10)  # larger value

def create_random_tree(
    depth: int,
    max_depth: int,
    n_variables: int,
    config: Optional[MutationConfig] = None
) -> Node:
    if depth >= max_depth or (depth > 0 and random.random() < 0.5):
        # Nodo foglia
        if random.random() < 0.7:
            return Node(value=f"x[{random.randint(0, n_variables - 1)}]")
        else:
            return Node(generate_constant())

    if random.random() < 0.5:
        # Operatore binario
        op = choose_operator()  # Scegli l'operatore pesato
        left = create_random_tree(depth + 1, max_depth, n_variables)
        right = create_random_tree(depth + 1, max_depth, n_variables)
        return validate_tree(Node(op=op, left=left, right=right), n_variables)
    else:
        # Operatore unario
        op = choose_operator()
        operand = create_random_tree(depth + 1, max_depth, n_variables)
        return validate_tree(Node(op=op, left=operand), n_variables)


def crossover(parent1: Node, parent2: Node) -> Node:
    """Effettua il crossover tra due individui."""
    if random.random() < 0.9:
        return parent1.copy()
    return parent2.copy()

# def calculate_fitness(tree: Node, x: np.ndarray, y_true: np.ndarray) -> float:
#     """Calcola la fitness di un individuo basata sull'errore quadratico medio."""
#     try:
#         y_pred = np.array([tree.evaluate(x[:, i]) for i in range(x.shape[1])])
#         y_pred = np.clip(y_pred, CLIP_MIN, CLIP_MAX)
#         y_pred = np.nan_to_num(y_pred, nan=0.0, posinf=CLIP_MAX, neginf=CLIP_MIN)  # Gestione di nan e inf
#         return np.mean((y_pred - y_true) ** 2)
#     except Exception:
#         return float('inf')

def calculate_complexity(node: Node) -> int:
    if node is None:
        return 0
    complexity = 1  # Base: 1 per ogni nodo
    
    # Definizione delle penalità
    HIGH_PENALTY_OPS = ['**', 'exp', 'log', 'mod']
    MEDIUM_PENALTY_OPS = ['/', 'tan', 'tanh', 'sqrt', 'log10', 'log2']
    LOW_PENALTY_OPS = ['+', '-', '*', 'sin', 'cos', 'sinh', 'cosh', 'abs']
    
    if node.op in HIGH_PENALTY_OPS:
        complexity += 3
    elif node.op in MEDIUM_PENALTY_OPS:
        complexity += 2
    elif node.op in LOW_PENALTY_OPS:
        complexity += 1
    complexity += calculate_complexity(node.left)
    complexity += calculate_complexity(node.right)
    return complexity




def calculate_fitness(tree: Node, x: np.ndarray, y_true: np.ndarray, lambda_penalty: float = 0.01) -> float:
    try:
        # Calcola la predizione
        y_pred = np.array([tree.evaluate(x[:, i]) for i in range(x.shape[1])])
        y_pred = np.nan_to_num(y_pred, nan=float('inf'), posinf=CLIP_MAX, neginf=CLIP_MIN)
        
        # Calcola l'MSE
        mse = np.mean((y_pred - y_true) ** 2)
        
        # Calcola la complessità
        complexity = calculate_complexity(tree)
        
        # Fitness totale
        fitness = mse + lambda_penalty * complexity
        return fitness
    except Exception:
        return float('inf')  # Penalizza alberi non validi


def tournament_selection(population: List[Node], fitness_scores: List[float], tournament_size: int = 3) -> Node:
    """Selezione tramite torneo."""
    competitors = random.sample(list(zip(population, fitness_scores)), tournament_size)
    winner = min(competitors, key=lambda x: x[1])  # Migliore fitness
    return winner[0]


def calculate_population_diversity(population: List[Node]) -> float:
    """Calcola la diversità della popolazione."""
    unique_trees = set(str(tree) for tree in population)
    return len(unique_trees) / len(population)

from collections import defaultdict

def maintain_diversity(population: List[Node], min_diversity: float, max_depth: int, n_variables: int):
    """Mantiene la diversità sostituendo individui simili."""
    current_diversity = calculate_population_diversity(population)
    # print(f"Diversità attuale: {current_diversity:.2f}")
    if current_diversity < min_diversity:
        # Raggruppa individui simili
        structures = defaultdict(list)
        for i, tree in enumerate(population):
            structures[str(tree)].append(i)

        # Sostituisci individui simili in eccesso
        for indices in structures.values():
            if len(indices) > 1 : # Tieni al massimo 2 di ogni struttura
                for idx in indices[1:]:
                    population[idx] = validate_tree(create_random_tree(0, max_depth, n_variables), n_variables)


    return population

# %%
# Parametri
POPULATION_SIZE = 500
MAX_DEPTH = 6
GENERATIONS = 20
MIN_DIVERSITY = 0.6
TOURNAMENT_SIZE = 3

# load dei dati
data = np.load('data/problem_2.npz')
x_train = data['x']
y_train = data['y']

N_VARIABLES = x_train.shape[0]


# # Inizializzazione della popolazione
population = [create_random_tree(0, MAX_DEPTH, N_VARIABLES) for _ in range(POPULATION_SIZE)]

## log print
print("Popolazione iniziale:")
for i, ind in enumerate(population):
    print(f"Individuo {i}: {ind}")

    
best_fitness = float('inf')

fitness_scores = [calculate_fitness(validate_tree(ind, n_variables = N_VARIABLES), x_train, y_train) for ind in population]

replacement_rate = 0.5
num_replacement = int(POPULATION_SIZE * replacement_rate)
for generation in range(GENERATIONS):
    parents = [tournament_selection(population, fitness_scores, TOURNAMENT_SIZE) for _ in range(2)]

    next_generation = []
    for i in range(0, POPULATION_SIZE, 2):
        child1 = crossover(parents[0], parents[1])
        child2 = crossover(parents[1], parents[0])

        child1 = mutate(child1, mutation_prob=0.4, max_depth=MAX_DEPTH, n_variables=N_VARIABLES)
        child2 = mutate(child2, mutation_prob=0.4, max_depth=MAX_DEPTH, n_variables=N_VARIABLES)

        next_generation.extend([validate_tree(child1, n_variables=N_VARIABLES), validate_tree(child2, n_variables=N_VARIABLES)])
    offspring_fitness = [calculate_fitness(ind, x_train, y_train) for ind in next_generation]

    for child, fitness in zip(next_generation[:num_replacement], offspring_fitness[:num_replacement]):
        least_fit_idx = np.argmax(fitness_scores)
        if fitness < fitness_scores[least_fit_idx]:
            population[least_fit_idx] = child
            fitness_scores[least_fit_idx] = fitness

            if fitness < best_fitness:
                best_fitness = fitness
                best_tree = child

    if calculate_population_diversity(population) < MIN_DIVERSITY:
        population = maintain_diversity(population, MIN_DIVERSITY, MAX_DEPTH, N_VARIABLES)


    div = calculate_population_diversity(population)
    print(f"Diversità: {div:.2f}")
    # if generation % 5 == 0:
    #     diversity = calculate_population_diversity(population)
    #     if diversity < MIN_DIVERSITY:
    #         num_to_replace = int(POPULATION_SIZE * 0.3)
    #         for i in range(num_to_replace):
    #             population[i] = create_random_tree(0, MAX_DEPTH, N_VARIABLES)
        



    print(f"Generazione {generation + 1}: Miglior fitness: {best_fitness}, Miglior individuo: {best_tree}")

print(f"Miglior individuo: {best_tree}")
print("Fitness sul training set:", calculate_fitness(best_tree, x_train, y_train))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 17
#      13 N_VARIABLES = x_train.shape[0]
#      16 # # Inizializzazione della popolazione
# ---> 17 population = [create_random_tree(0, MAX_DEPTH, N_VARIABLES) for _ in range(POPULATION_SIZE)]
#      19 ## log print
#      20 print("Popolazione iniziale:")
#
# Cell In[30], line 406, in create_random_tree(depth, max_depth, n_variables, config)
#     404     op = choose_operator()  # Scegli l'operatore pesato
#     405     left = create_random_tree(depth + 1, max_depth, n_variables)
# --> 406     right = create_random_tree(depth + 1, max_depth, n_variables)
#     407     return validate_tree(Node(op=op, left=left, right=right), n_variables)
#     408 else:
#     409     # Operatore unario
#
# Cell In[30], line 407, in create_random_tree(depth, max_depth, n_variables, config)
#     405     left = create_random_tree(depth + 1, max_depth, n_variables)
#     406     right = create_random_tree(depth + 1, max_depth, n_variables)
# --> 407     return validate_tree(Node(op=op, left=left, right=right), n_variables)
#     408 else:
#     409     # Operatore unario
#     410     op = choose_operator()
#
# Cell In[30], line 304, in validate_tree(node, n_variables)
#     302 new_node.right = validate_tree(node.right, n_variables)
#     303 if new_node.op == '/':
# --> 304     if is_zero(new_node.right):  # Se il denominatore può essere zero
#     305         return Node(value=generate_constant())
#     306 elif new_node.op == '**':
#
# Cell In[30], line 269, in is_zero(node)
#     267 """Verifica se il sottoalbero restituisce zero."""
#     268 # Versione semplificata: controlla se è una costante zero
# --> 269 return node.value == 0 or (node.op is None and float(node.value) == 0.0)
#
# ValueError: could not convert string to float: 'x[1]'

# %%
def genetic_algorithm(filepath, POPULATION_SIZE = 300, MAX_DEPTH = 6, GENERATIONS = 100, MIN_DIVERSITY = 0.6, TOURNAMENT_SIZE = 3):
    # load dei dati
    data = np.load(filepath)
    x_train = data['x']
    y_train = data['y']

    N_VARIABLES = x_train.shape[0]


    # # Inizializzazione della popolazione
    population = [validate_tree(create_random_tree(0, MAX_DEPTH, N_VARIABLES), N_VARIABLES) for _ in range(POPULATION_SIZE)]

    best_fitness = float('inf')

    fitness_scores = [calculate_fitness(ind, x_train, y_train) for ind in population]

    replacement_rate = 0.5
    num_replacement = int(POPULATION_SIZE * replacement_rate)
    for generation in range(GENERATIONS):
        parents = [tournament_selection(population, fitness_scores, TOURNAMENT_SIZE) for _ in range(2)]

        next_generation = []
        for i in range(0, POPULATION_SIZE, 2):
            child1 = crossover(parents[0], parents[1])
            child2 = crossover(parents[1], parents[0])

            child1 = validate_tree(child1, N_VARIABLES)
            child2 = validate_tree(child2, N_VARIABLES)


            child1 = mutate(child1, mutation_prob=0.4, max_depth=MAX_DEPTH, n_variables=N_VARIABLES)
            child2 = mutate(child2, mutation_prob=0.4, max_depth=MAX_DEPTH, n_variables=N_VARIABLES)

            child1 = validate_tree(child1, N_VARIABLES)
            child2 = validate_tree(child2,  N_VARIABLES)


            next_generation.extend([child1, child2])
        offspring_fitness = [calculate_fitness(ind, x_train, y_train) for ind in next_generation]

        for child, fitness in zip(next_generation[:num_replacement], offspring_fitness[:num_replacement]):
            least_fit_idx = np.argmax(fitness_scores)
            if fitness < fitness_scores[least_fit_idx]:
                population[least_fit_idx] = child
                fitness_scores[least_fit_idx] = fitness

                if fitness < best_fitness:
                    best_fitness = fitness
                    best_tree = child

        if calculate_population_diversity(population) < MIN_DIVERSITY and generation % 5 == 0:
            population = maintain_diversity(population, MIN_DIVERSITY, MAX_DEPTH, N_VARIABLES)


        # div = calculate_population_diversity(population)
        # print(f"Diversità: {div:.2f}")
        # if generation % 5 == 0:
        #     diversity = calculate_population_diversity(population)
        #     if diversity < MIN_DIVERSITY:
        #         num_to_replace = int(POPULATION_SIZE * 0.3)
        #         for i in range(num_to_replace):
        #             population[i] = create_random_tree(0, MAX_DEPTH, N_VARIABLES)
        print(f"Generazione {generation + 1}: Miglior fitness: {best_fitness}, Miglior individuo: {best_tree}")



        # print(f"Generazione {generation + 1}: Miglior fitness: {best_fitness}, Miglior individuo: {best_tree}")
    print(f"File {filepath}")
    print(f"Miglior individuo: {best_tree}")
    print("Fitness sul training set:", calculate_fitness(best_tree, x_train, y_train))

# %%
filepath0 = 'data/problem_0.npz'
filepath1 = 'data/problem_1.npz'
filepath2 = 'data/problem_2.npz'
filepath3 = 'data/problem_3.npz'
filepath4 = 'data/problem_4.npz'
filepath5 = 'data/problem_5.npz'
filepath6 = 'data/problem_6.npz'
filepath7 = 'data/problem_7.npz'
filepath8 = 'data/problem_8.npz'

genetic_algorithm(filepath0)
genetic_algorithm(filepath1)
genetic_algorithm(filepath2)
genetic_algorithm(filepath3)
genetic_algorithm(filepath4)
genetic_algorithm(filepath5)
genetic_algorithm(filepath6)
genetic_algorithm(filepath7)
genetic_algorithm(filepath8)
# Out:
# Generazione 1: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 2: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 3: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 4: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 5: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 6: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 7: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 8: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 9: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 10: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 11: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 12: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 13: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 14: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 15: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 16: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 17: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 18: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 19: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 20: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 21: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 22: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 23: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 24: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 25: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 26: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 27: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 28: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 29: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 30: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 31: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 32: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 33: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 34: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 35: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 36: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 37: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 38: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 39: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 40: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 41: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 42: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 43: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 44: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 45: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 46: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 47: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 48: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 49: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 50: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 51: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 52: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 53: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 54: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 55: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 56: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 57: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 58: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 59: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 60: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 61: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 62: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 63: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 64: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 65: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 66: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 67: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 68: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 69: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 70: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 71: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 72: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 73: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 74: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 75: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 76: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 77: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 78: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 79: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 80: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 81: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 82: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 83: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 84: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 85: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 86: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 87: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 88: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 89: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 90: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 91: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 92: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 93: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 94: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 95: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 96: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 97: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 98: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 99: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# Generazione 100: Miglior fitness: 0.020675664005502033, Miglior individuo: x[0]
# File data/problem_0.npz
# Miglior individuo: x[0]
# Fitness sul training set: 0.020675664005502033
# Generazione 1: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 2: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 3: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 4: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 5: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 6: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 7: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 8: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 9: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 10: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 11: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 12: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 13: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 14: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 15: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 16: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 17: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 18: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 19: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 20: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 21: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 22: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 23: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 24: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 25: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 26: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 27: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 28: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 29: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 30: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 31: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 32: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 33: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 34: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 35: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 36: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 37: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 38: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 39: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 40: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 41: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 42: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 43: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 44: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 45: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 46: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 47: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 48: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 49: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 50: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 51: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 52: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 53: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 54: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 55: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 56: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 57: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 58: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 59: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 60: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 61: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 62: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 63: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 64: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 65: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 66: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 67: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 68: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 69: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 70: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 71: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 72: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 73: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 74: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 75: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 76: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# Generazione 77: Miglior fitness: 0.013281545223894704, Miglior individuo: x[0]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 12
#       9 filepath8 = 'data/problem_8.npz'
#      11 genetic_algorithm(filepath0)
# ---> 12 genetic_algorithm(filepath1)
#      13 genetic_algorithm(filepath2)
#      14 genetic_algorithm(filepath3)
#
# Cell In[26], line 34, in genetic_algorithm(filepath, POPULATION_SIZE, MAX_DEPTH, GENERATIONS, MIN_DIVERSITY, TOURNAMENT_SIZE)
#      31 child1 = mutate(child1, mutation_prob=0.4, max_depth=MAX_DEPTH, n_variables=N_VARIABLES)
#      32 child2 = mutate(child2, mutation_prob=0.4, max_depth=MAX_DEPTH, n_variables=N_VARIABLES)
# ---> 34 child1 = validate_tree(child1, N_VARIABLES)
#      35 child2 = validate_tree(child2,  N_VARIABLES)
#      38 next_generation.extend([child1, child2])
#
# Cell In[24], line 232, in validate_tree(node, n_variables)
#     230 # Valida operatori unari
#     231 if node.op in UNARY_OPERATORS:
# --> 232     if node.op == 'log' and (node.left is None or node.left.evaluate([0]) <= 0):
#     233         return Node(generate_constant())
#     235 # Valida operatori binari
#
# TypeError: '<=' not supported between instances of 'NoneType' and 'int'

# %%
filepath8 = 'data/problem_8.npz'
# filepath4 = 'data/problem_4.npz'
# filepath5 = 'data/problem_5.npz'
# filepath6 = 'data/problem_6.npz'
# filepath7 = 'data/problem_7.npz'
# filepath8 = 'data/problem_8.npz'

genetic_algorithm(filepath8)
# genetic_algorithm(filepath4)
# genetic_algorithm(filepath5)
# genetic_algorithm(filepath6)
# genetic_algorithm(filepath7)
# genetic_algorithm(filepath8)
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[5], line 8
#       1 filepath8 = 'data/problem_8.npz'
#       2 # filepath4 = 'data/problem_4.npz'
#       3 # filepath5 = 'data/problem_5.npz'
#       4 # filepath6 = 'data/problem_6.npz'
#       5 # filepath7 = 'data/problem_7.npz'
#       6 # filepath8 = 'data/problem_8.npz'
# ----> 8 genetic_algorithm(filepath8)
#       9 # genetic_algorithm(filepath4)
#      10 # genetic_algorithm(filepath5)
#      11 # genetic_algorithm(filepath6)
#      12 # genetic_algorithm(filepath7)
#      13 # genetic_algorithm(filepath8)
#
# Cell In[3], line 11, in genetic_algorithm(filepath, POPULATION_SIZE, MAX_DEPTH, GENERATIONS, MIN_DIVERSITY, TOURNAMENT_SIZE)
#       7 N_VARIABLES = x_train.shape[0]
#      10 # # Inizializzazione della popolazione
# ---> 11 population = [validate_tree(create_random_tree(0, MAX_DEPTH, N_VARIABLES), N_VARIABLES) for _ in range(POPULATION_SIZE)]
#      13 best_fitness = float('inf')
#      15 fitness_scores = [calculate_fitness(ind, x_train, y_train) for ind in population]
#
# Cell In[2], line 265, in create_random_tree(depth, max_depth, n_variables, config)
#     263     op = choose_operator()  # Scegli l'operatore pesato
#     264     left = create_random_tree(depth + 1, max_depth, n_variables)
# --> 265     right = create_random_tree(depth + 1, max_depth, n_variables)
#     266     return validate_tree(Node(op=op, left=left, right=right), n_variables)
#     267 else:
#     268     # Operatore unario
#
# Cell In[2], line 270, in create_random_tree(depth, max_depth, n_variables, config)
#     267 else:
#     268     # Operatore unario
#     269     op = choose_operator()
# --> 270     operand = create_random_tree(depth + 1, max_depth, n_variables)
#     271     return validate_tree(Node(op=op, left=operand), n_variables)
#
# Cell In[2], line 264, in create_random_tree(depth, max_depth, n_variables, config)
#     261 if random.random() < 0.5:
#     262     # Operatore binario
#     263     op = choose_operator()  # Scegli l'operatore pesato
# --> 264     left = create_random_tree(depth + 1, max_depth, n_variables)
#     265     right = create_random_tree(depth + 1, max_depth, n_variables)
#     266     return validate_tree(Node(op=op, left=left, right=right), n_variables)
#
# Cell In[2], line 264, in create_random_tree(depth, max_depth, n_variables, config)
#     261 if random.random() < 0.5:
#     262     # Operatore binario
#     263     op = choose_operator()  # Scegli l'operatore pesato
# --> 264     left = create_random_tree(depth + 1, max_depth, n_variables)
#     265     right = create_random_tree(depth + 1, max_depth, n_variables)
#     266     return validate_tree(Node(op=op, left=left, right=right), n_variables)
#
# Cell In[2], line 266, in create_random_tree(depth, max_depth, n_variables, config)
#     264     left = create_random_tree(depth + 1, max_depth, n_variables)
#     265     right = create_random_tree(depth + 1, max_depth, n_variables)
# --> 266     return validate_tree(Node(op=op, left=left, right=right), n_variables)
#     267 else:
#     268     # Operatore unario
#     269     op = choose_operator()
#
# Cell In[2], line 325, in validate_tree(node, n_variables)
#     322         return Node(value=random.uniform(-1, 1))  # Sostituisci potenza negativa
#     324 if node.left:
# --> 325     node.left = validate_tree(node.left, n_variables)
#     326 if node.right:
#     327     node.right = validate_tree(node.right, n_variables)
#
# Cell In[2], line 325, in validate_tree(node, n_variables)
#     322         return Node(value=random.uniform(-1, 1))  # Sostituisci potenza negativa
#     324 if node.left:
# --> 325     node.left = validate_tree(node.left, n_variables)
#     326 if node.right:
#     327     node.right = validate_tree(node.right, n_variables)
#
#     [... skipping similar frames: validate_tree at line 325 (2961 times)]
#
# Cell In[2], line 325, in validate_tree(node, n_variables)
#     322         return Node(value=random.uniform(-1, 1))  # Sostituisci potenza negativa
#     324 if node.left:
# --> 325     node.left = validate_tree(node.left, n_variables)
#     326 if node.right:
#     327     node.right = validate_tree(node.right, n_variables)
#
# Cell In[2], line 310, in validate_tree(node, n_variables)
#     307     return Node(value=random.uniform(-1, 1))
#     309 # Assicura che tutte le variabili di input siano presenti
# --> 310 node = ensure_all_variables_in_tree(node, n_variables)
#     312 # Valida operatori unari
#     313 if node.op in UNARY_OPERATORS:
#
# Cell In[2], line 151, in ensure_all_variables_in_tree(tree, n_variables)
#     148     tree = new_leaf
#     149 else:
#     150     # Inserisci la nuova foglia in un punto casuale dell'albero
# --> 151     insert_point = random.choice(get_all_nodes(tree))
#     152     if insert_point.left is None:
#     153         insert_point.left = new_leaf
#
# Cell In[2], line 174, in get_all_nodes(node)
#     172     traverse(node.left)
#     173     traverse(node.right)
# --> 174 traverse(node)
#     175 return nodes
#
# Cell In[2], line 172, in get_all_nodes.<locals>.traverse(node)
#     170     return
#     171 nodes.append(node)
# --> 172 traverse(node.left)
#     173 traverse(node.right)
#
# Cell In[2], line 172, in get_all_nodes.<locals>.traverse(node)
#     170     return
#     171 nodes.append(node)
# --> 172 traverse(node.left)
#     173 traverse(node.right)
#
#     [... skipping similar frames: get_all_nodes.<locals>.traverse at line 172 (1 times)]
#
# Cell In[2], line 172, in get_all_nodes.<locals>.traverse(node)
#     170     return
#     171 nodes.append(node)
# --> 172 traverse(node.left)
#     173 traverse(node.right)
#
# RecursionError: maximum recursion depth exceeded

# %%
import numpy as np
import random

# Operatori e funzioni supportate
OPERATORS = ['+', '-', '*', '/']
FUNCTIONS = ['sin', 'cos', 'exp', 'log']
class Node:
    def __init__(self, value, left=None, right=None):
        self.value = value
        self.left = left
        self.right = right

    def evaluate(self, x):
        try:
            if self.value in OPERATORS:
                left_val = self.left.evaluate(x)
                right_val = self.right.evaluate(x)
                # Gestione di divisioni per zero
                if self.value == '/' and np.any(right_val == 0):
                    return 1e10  # Penalità per divisione per zero
                result = eval(f"{left_val} {self.value} {right_val}")
                return np.nan_to_num(result, nan=1e10, posinf=1e10, neginf=1e10)
            elif self.value in FUNCTIONS:
                operand_val = self.left.evaluate(x)
                # Gestione di logaritmi negativi o nulli
                if self.value == 'log' and np.any(operand_val <= 0):
                    return 1e10  # Penalità per logaritmi invalidi
                result = eval(f"np.{self.value}({operand_val})")
                return np.nan_to_num(result, nan=1e10, posinf=1e10, neginf=1e10)
            elif isinstance(self.value, str) and self.value.startswith("x["):
                return eval(self.value)
            else:
                return float(self.value)
        except Exception as e:
            print(f"Errore durante la valutazione del nodo {self}: {e}")
            return 1e10  # Penalità per errori


    def __str__(self):
        if self.left and self.right:
            return f"({self.left} {self.value} {self.right})"
        elif self.left:
            return f"{self.value}({self.left})"
        else:
            return str(self.value)

def safe_generate_leaf(variable_count):
    """
    Genera una foglia valida (variabile o costante) garantendo che divisori e input a log siano validi.
    """
    if random.random() < 0.7:
        var_index = random.randint(0, variable_count - 1)
        return Node(f"x[{var_index}]")
    else:
        value = random.uniform(0.1, 1) if random.random() < 0.5 else random.uniform(-1, -0.1)  # Evita 0 per divisori
        return Node(f"{value:.3f}")

# Funzioni per generare alberi casuali
def generate_random_tree(variable_count, max_depth=3, ensure_all_vars=False):
    used_vars = set()

    def helper(depth):
        nonlocal used_vars
        if depth == 0 or (depth > 1 and random.random() < 0.3):
            leaf = safe_generate_leaf(variable_count)
            if leaf.value.startswith("x["):
                var_index = int(leaf.value[2:-1])
                used_vars.add(var_index)
            return leaf

        if random.random() < 0.5:
            left = helper(depth - 1)
            right = helper(depth - 1)
            return Node(random.choice(OPERATORS), left, right)
        else:
            operand = helper(depth - 1)
            return Node(random.choice(FUNCTIONS), operand)

    tree = helper(max_depth)


    # Se richiesto, garantire che tutte le variabili siano incluse
    if ensure_all_vars:
        missing_vars = [Node(f"x[{i}]") for i in range(variable_count) if i not in used_vars]
        for var in missing_vars:
            tree = Node('+', tree, var)

    return tree

# Funzione per verificare la conformità dei vincoli
# def ensure_all_variables(tree, variable_count):
#     used_vars = set()

#     def traverse(node):
#         if node is None:
#             return
#         if isinstance(node.value, str) and node.value.startswith("x["):
#             var_index = int(node.value[2:-1])
#             used_vars.add(var_index)
#         traverse(node.left)
#         traverse(node.right)

#     traverse(tree)

#     missing_vars = [Node(f"x[{i}]") for i in range(variable_count) if i not in used_vars]
#     for var in missing_vars:
#         tree = Node('+', tree, var)

#     return tree

# Inizializzazione della popolazione
def initialize_population(population_size, variable_count, max_depth=3):
    return [generate_random_tree(variable_count, max_depth, ensure_all_vars=False) for _ in range(population_size)]

# Calcolo della fitness
def calculate_fitness(tree, x, y_true):
    try:
        y_pred = np.array([tree.evaluate(x[:, i]) for i in range(x.shape[1])])
        y_pred = np.nan_to_num(y_pred)  # Converte NaN e inf in 0
        return np.mean((y_pred - y_true) ** 2)
    except Exception as e:
        print(f"Errore durante la valutazione della fitness per {tree}: {e}")
        return float('inf')

# Operazioni genetiche
def crossover(parent1, parent2):
    if random.random() < 0.5:
        return parent1
    return parent2

def mutate(tree, variable_count, max_depth=3):
    if random.random() < 0.5:
        return generate_random_tree(variable_count, max_depth, ensure_all_vars=False)
    return tree

# %%
# Inizializzazione
data = np.load('problem_0.npz')
x_train = data['x']
y_train = data['y']


# Parametri
POPULATION_SIZE = 100
VARIABLE_COUNT = x_train.shape[0]
MAX_DEPTH = 5

GENERATIONS = 50

# Inizializzazione della popolazione
population = initialize_population(POPULATION_SIZE, VARIABLE_COUNT, MAX_DEPTH)


# Esempio di utilizzo
POPULATION_SIZE = 50
MAX_DEPTH = 3
N_VARIABLES = 2

population = [create_random_tree(0, MAX_DEPTH, N_VARIABLES) for _ in range(POPULATION_SIZE)]
print("Diversità iniziale:", structural_diversity(population))

population = maintain_diversity(population, threshold=5.0)
print("Diversità mantenuta:", structural_diversity(population))


for generation in range(GENERATIONS):
    fitness_scores = [calculate_fitness(ind, x_train, y_train) for ind in population]

    # Selezione
    sorted_population = sorted(zip(population, fitness_scores), key=lambda x: x[1])
    parent1 = sorted_population[0][0]
    parent2 = sorted_population[1][0]

    # Crossover
    child = crossover(parent1, parent2)

    # Mutazione
    child = mutate(child, VARIABLE_COUNT, MAX_DEPTH)

    # Calcola la fitness del nuovo individuo
    child_fitness = calculate_fitness(child, x_train, y_train)

    # Sostituzione (steady state: sostituisce il peggiore)
    worst_index = fitness_scores.index(max(fitness_scores))
    population[worst_index] = child

    # Log della generazione
    best_fitness = min(fitness_scores)
    print(f"Generazione {generation + 1}: Miglior fitness: {best_fitness:.6f}")
    print(f"Individuo migliore: {population[fitness_scores.index(best_fitness)]}")

# Miglior individuo finale
fitness_scores = [calculate_fitness(ind, x_train, y_train) for ind in population]
best_index = fitness_scores.index(min(fitness_scores))
print(f"Miglior individuo: {population[best_index]} con fitness {fitness_scores[best_index]:.6f}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[107], line 23
#      20 MAX_DEPTH = 3
#      21 N_VARIABLES = 2
# ---> 23 population = [create_random_tree(0, MAX_DEPTH, N_VARIABLES) for _ in range(POPULATION_SIZE)]
#      24 print("Diversità iniziale:", structural_diversity(population))
#      26 population = maintain_diversity(population, threshold=5.0)
#
# Cell In[105], line 202, in create_random_tree(depth, max_depth, n_variables, config)
#     200 op = random.choice(UNARY_OPERATORS)
#     201 operand = create_random_tree(depth + 1, max_depth, n_variables)
# --> 202 return validate_tree(Node(op=op, left=operand))
#
# TypeError: Node.__init__() got an unexpected keyword argument 'op'
